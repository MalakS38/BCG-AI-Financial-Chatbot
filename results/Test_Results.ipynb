# %% [markdown]
# # AI-powered financial chatbot

# %%
import pandas as pd

# %%
df = pd.read_csv('MSFT_TSLA_AAPL.csv')
# Out:
#      Company  Fiscal Year  Total Revenue    Net Income  Total Assets  \
# 0      Apple       2022.0   3.943280e+11  9.980300e+10  3.527550e+11
# 1      Apple       2023.0   3.832850e+11  9.699500e+10  3.525830e+11
# 2      Apple       2024.0   3.910350e+11  9.373600e+10  3.649800e+11
# 3  Microsoft       2022.0   1.982700e+11  7.273800e+10  3.648400e+11
# 4  Microsoft       2023.0   2.119150e+11  7.236100e+10  4.119760e+11
#
#    Total Liabilities  Cash Flow from Operating Activities  Revenue Growth (%)  \
# 0       3.020830e+11                         1.221510e+11                0.00
# 1       2.904370e+11                         1.105430e+11               -2.80
# 2       3.080300e+11                         1.182540e+11                2.02
# 3       1.982980e+11                         8.903500e+10                0.00
# 4       2.057530e+11                         8.758200e+10                6.88
#
#    Net Income Growth (%)  Asset Growth (%)  Operating Cash Flow Growth (%)  \
# ...

# %% [markdown]
# # Supported Queries:
#
# - Total Revenue
#
# - Net Income
#
# - Debt Ratio
#
# - Cash Flow
#
# - Revenue Growth (%)
#
# - Net Income Growth (%)
#
# - Asset Growth (%)
#
# - Operating Cash Flow Growth (%)

# %%
# %run chatbot.py
# Out:
# Hello! Welcome to the AI-Driven Financial Chatbot
#
# Please select the company name from below:
# 1. Microsoft
# 2. Tesla
# 3. Apple
# Enter the company name (Microsoft/Tesla/Apple):  Apple
# You’ve selected Apple.
# You can ask about:
#  - Total Revenue
#  - Net Income Change
#  - Debt Ratio
#  - Cash Flow
#  - Revenue Growth (%)
#  - Net Income Growth (%)
#  - Asset Growth (%)
#  - Operating Cash Flow Growth (%)
# Type 'back' to choose another company or 'exit' to quit.
# Ask your financial question about Apple:  What's Apples Total Revenue in 2023
# Apple's total revenue in 2023 was $383,285,000,000.0.
# Ask your financial question about Apple:  what about its Debt Ratio
# Apple's debt ratio in 2024.0 was 84.0%.
# Ask your financial question about Apple:  what's Apple cash flow from operations?
# Apple's operating cash flow in 2024.0 was $118,254,000,000.0.
# Ask your financial question about Apple:  back
# Returning to company selection...
# ...
